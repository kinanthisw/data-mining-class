# %% [markdown]
# # Data Integration

# %%
### Data integration
import pandas as pd
import numpy as np

# %%
#load data
#data berasalh dari UCI, student performance data set
siswa = pd.read_csv (r'E:\Data Mining\student-mat.csv', sep = ';')
kategori = pd.read_csv(r'E:\Data Mining\student-categoric.csv', sep =';')
siswa
# Out:
#       id school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0      1     GP   F   18       U     GT3       A     4     4   at_home
# 1      2     GP   F   17       U     GT3       T     1     1   at_home
# 2      3     GP   F   15       U     LE3       T     1     1   at_home
# 3      4     GP   F   15       U     GT3       T     4     2    health
# 4      5     GP   F   16       U     GT3       T     3     3     other
# 5      6     GP   M   16       U     LE3       T     4     3  services
# 6      7     GP   M   16       U     LE3       T     2     2     other
# 7      8     GP   F   17       U     GT3       A     4     4     other
# 8      9     GP   M   15       U     LE3       A     3     2  services
# 9     10     GP   M   15       U     GT3       T     3     4     other
# 10    11     GP   F   15       U     GT3       T     4     4   teacher
# 11    12     GP   F   15       U     GT3       T     2     1  services
# ...

# %%
siswa.head()
# Out:
#    id school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0   1     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1   2     GP   F   17       U     GT3       T     1     1  at_home     other
# 2   3     GP   F   15       U     LE3       T     1     1  at_home     other
# 3   4     GP   F   15       U     GT3       T     4     2   health  services
# 4   5     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  absences
# 0  course   mother           2          2         6
# 1  course   father           1          2         4
# 2   other   mother           1          2        10
# 3    home   mother           1          3         2
# 4    home   father           1          2         4

# %%
kategori
# Out:
#       id  failures schoolsup famsup paid activities nursery higher internet  \
# 0      1         0       yes     no   no         no     yes    yes       no
# 1      2         0        no    yes   no         no      no    yes      yes
# 2      3         3       yes     no  yes         no     yes    yes      yes
# 3      4         0        no    yes  yes        yes     yes    yes      yes
# 4      5         0        no    yes  yes         no     yes    yes       no
# 5      6         0        no    yes  yes        yes     yes    yes      yes
# 6      7         0        no     no   no         no     yes    yes      yes
# 7      8         0       yes    yes   no         no     yes    yes       no
# 8      9         0        no    yes  yes         no     yes    yes      yes
# 9     10         0        no    yes  yes        yes     yes    yes      yes
# 10    11         0        no    yes  yes         no     yes    yes      yes
# ...

# %%
kategori.head()
# Out:
#    id  failures schoolsup famsup paid activities nursery higher internet  \
# 0   1         0       yes     no   no         no     yes    yes       no
# 1   2         0        no    yes   no         no      no    yes      yes
# 2   3         3       yes     no  yes         no     yes    yes      yes
# 3   4         0        no    yes  yes        yes     yes    yes      yes
# 4   5         0        no    yes  yes         no     yes    yes       no
#
#   romantic  famrel  freetime  goout  Dalc  Walc  health
# 0       no       4         3      4     1     1       3
# 1       no       5         3      3     1     1       3
# 2       no       4         3      2     2     3       3
# 3      yes       3         2      2     1     1       5
# 4       no       4         3      2     1     2       5

# %%
# merge data based on ID
data = pd.merge(siswa, kategori, on='id')
data
# Out:
#       id school sex  age address famsize Pstatus  Medu  Fedu      Mjob  ...    \
# 0      1     GP   F   18       U     GT3       A     4     4   at_home  ...
# 1      2     GP   F   17       U     GT3       T     1     1   at_home  ...
# 2      3     GP   F   15       U     LE3       T     1     1   at_home  ...
# 3      4     GP   F   15       U     GT3       T     4     2    health  ...
# 4      5     GP   F   16       U     GT3       T     3     3     other  ...
# 5      6     GP   M   16       U     LE3       T     4     3  services  ...
# 6      7     GP   M   16       U     LE3       T     2     2     other  ...
# 7      8     GP   F   17       U     GT3       A     4     4     other  ...
# 8      9     GP   M   15       U     LE3       A     3     2  services  ...
# 9     10     GP   M   15       U     GT3       T     3     4     other  ...
# 10    11     GP   F   15       U     GT3       T     4     4   teacher  ...
# ...

# %%
# insert new colomn
# Family edu bernilai 1 jika pendidikan kedua orang tua anak kategori 4
data['Family Edu']=np.where(((data['Medu']==4) & (data['Fedu']==4)) ,'1','0')
data
# Out:
#       id school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0      1     GP   F   18       U     GT3       A     4     4   at_home
# 1      2     GP   F   17       U     GT3       T     1     1   at_home
# 2      3     GP   F   15       U     LE3       T     1     1   at_home
# 3      4     GP   F   15       U     GT3       T     4     2    health
# 4      5     GP   F   16       U     GT3       T     3     3     other
# 5      6     GP   M   16       U     LE3       T     4     3  services
# 6      7     GP   M   16       U     LE3       T     2     2     other
# 7      8     GP   F   17       U     GT3       A     4     4     other
# 8      9     GP   M   15       U     LE3       A     3     2  services
# 9     10     GP   M   15       U     GT3       T     3     4     other
# 10    11     GP   F   15       U     GT3       T     4     4   teacher
# 11    12     GP   F   15       U     GT3       T     2     1  services
# ...

# %%
# delete colomn
data1 = data.drop(['nursery','higher','internet'], axis=1)
data1
# Out:
#       id school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0      1     GP   F   18       U     GT3       A     4     4   at_home
# 1      2     GP   F   17       U     GT3       T     1     1   at_home
# 2      3     GP   F   15       U     LE3       T     1     1   at_home
# 3      4     GP   F   15       U     GT3       T     4     2    health
# 4      5     GP   F   16       U     GT3       T     3     3     other
# 5      6     GP   M   16       U     LE3       T     4     3  services
# 6      7     GP   M   16       U     LE3       T     2     2     other
# 7      8     GP   F   17       U     GT3       A     4     4     other
# 8      9     GP   M   15       U     LE3       A     3     2  services
# 9     10     GP   M   15       U     GT3       T     3     4     other
# 10    11     GP   F   15       U     GT3       T     4     4   teacher
# 11    12     GP   F   15       U     GT3       T     2     1  services
# ...

# %%
# Drop baris ke-300 awal
a=list(range(301))
data2 = data.drop(a)
data2
# Out:
#       id school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 301  302     GP   M   17       U     LE3       T     4     4     other
# 302  303     GP   F   17       U     GT3       T     4     2     other
# 303  304     GP   F   17       U     GT3       T     3     2    health
# 304  305     GP   M   19       U     GT3       T     3     3     other
# 305  306     GP   F   18       U     GT3       T     2     4  services
# 306  307     GP   M   20       U     GT3       A     3     2  services
# 307  308     GP   M   19       U     GT3       T     4     4   teacher
# 308  309     GP   M   19       R     GT3       T     3     3     other
# 309  310     GP   F   19       U     LE3       T     1     1   at_home
# 310  311     GP   F   19       U     LE3       T     1     2  services
# 311  312     GP   F   19       U     GT3       T     2     1   at_home
# 312  313     GP   M   19       U     GT3       T     1     2     other
# ...
